# %%
# Example of an entity resolution approach: compiling available information about entities 
# (here, fictional persons) from multiple tables. This starts with a (multi-table) record 
# linkage step as before, and then clusters the results by entity.

# %%
import numpy as np
import numbers
import pandas as pd

import phonetics

from splink.duckdb.linker import DuckDBLinker
import splink.duckdb.comparison_library as cl
import splink.duckdb.comparison_template_library as ctl

# %%
import IPython

# %%
import vega

# %% [markdown]
# Setup
# ==

# %% [markdown]
# Vega setup for charts
# --
# Splink uses Vega for inline charts. We need a bit of setup to make sure these are displayed correctly.

# %%
# !jupyter nbextension install --sys-prefix --py vega

# %%
# !jupyter nbextension enable vega --py --sys-prefix
# Out:
# Enabling notebook extension jupyter-vega/extension...
#       - Validating: ok

# %%
# # A minimal example for debugging:
# vega.Vega({
#     "$schema": "https://vega.github.io/schema/vega-lite/v4.json",
#     "data": {
#         "values": [
#             {"a": "A", "b": 28},
#             {"a": "B", "b": 55},
#             {"a": "C", "b": 43},
#         ]
#     },
#     "mark": "bar",
#     "encoding": {
#         "x": {"field": "b", "type": "quantitative"},
#         "y": {"field": "a", "type": "nominal"}
#     }
# })

# %% [markdown]
# Data
# ==

# %% [markdown]
# Tables
# --

# %%
table1 = pd.read_csv('data/interim/table1_with_duplicates.csv', dtype=str)
table2 = pd.read_csv('data/interim/table2_with_duplicates.csv', dtype=str)
table3 = pd.read_csv('data/interim/table3_with_duplicates.csv', dtype=str)
table4 = pd.read_csv('data/interim/table4_with_duplicates.csv', dtype=str)

# %% [markdown]
# Feature vector
# --

# %%
# In practice we would first need to preprocess all tables to make them fit a standardised format --
# we can skip this here as the test data already comes standardised.

# %%
# Label them
table1.insert(0, 'Source', 'Table 1')
table2.insert(0, 'Source', 'Table 2')
table3.insert(0, 'Source', 'Table 3')
table4.insert(0, 'Source', 'Table 4')

# Combine to single DF
features = pd.concat([
    table1, table2, table3, table4
])
features.sample(5)
# Out:
#        Source    unique_id                         city postcode  \
# 5763  Table 1    Q389497-3                    barnsbury   n7 6lj
# 920   Table 1  Q98761006-3                   birmingham  b29 4jh
# 6047  Table 3   Q7790900-5  kingston upon hull, city of  hu8 8bz
# 1911  Table 2  Q43127454-7                        wales      NaN
# 9018  Table 1   Q5393276-4                   hillingdon  ub5 6hw
#
#                   full_name first_and_surname first_name    surname  \
# 5763   benjamin glover laws     benjamin laws   benjamin       laws
# 920   frank henry partridge   frank partridge      frank  partridge
# 6047           humphry ward      humphry ward    humphry       ward
# 1911            david bevan       david bevan      david      bevan
# 9018           ernest hirst      ernest hirst     ernest      hirst
#
#              dob gender    cluster
# 5763  1861-02-06   male    Q389497
# 920   1849-01-11   male  Q98761006
# 6047  1842-11-09   male   Q7790900
# 1911  1852-01-01   male  Q43127454
# 9018  1855-02-27   male   Q5393276

# %% [markdown]
# Entity resolution
# ==
# Based on https://moj-analytical-services.github.io/splink/demos/examples/duckdb/deduplicate_50k_synthetic.html
#
# Entity resolution of person names across all data sets. This then also effectively deduplicates any entries within each individual source table.

# %% [markdown]
# Settings
# --

# %%
person_match_settings = {
    "link_type": "dedupe_only",
    "unique_id_column_name": "unique_id",
    
    # Blocking, for performance
    "blocking_rules_to_generate_predictions": [
        "l.postcode = r.postcode",
    ],
    "comparisons": [
        cl.exact_match("city", term_frequency_adjustments=False),
        
        ctl.name_comparison("first_name"), 
        ctl.name_comparison("surname"), 
#         ctl.name_comparison("full_name"), 
#         ctl.forename_surname_comparison("first_name", "surname"),
    ],
    
    # Needed for waterfall charts of results
    "retain_intermediate_calculation_columns": True,
    "retain_matching_columns": True,
}

# %% [markdown]
# Training
# --

# %%
person_linker = DuckDBLinker(
    [features],
    person_match_settings)

# %%
person_linker.missingness_chart()
# Out:
# alt.LayerChart(...)

# %%
person_linker.estimate_probability_two_random_records_match(
    #  A list of deterministic matching rules that should be designed to admit 
    # very few (none if possible) false positives:
    [
        "l.city = r.city and l.full_name = r.full_name",
    ], 
    recall=0.9)
# Out:
# Probability two random records match is estimated to be  3.77e-05.
# This means that amongst all possible pairwise record comparisons, one in 26,534.30 are expected to match.  With 1,279,041,753 total possible comparisons, we expect a total of around 48,203.33 matching pairs

# %%
# Estimate U
person_linker.estimate_u_using_random_sampling(max_pairs=1e6, seed=1)
# Out:
# ----- Estimating u probabilities using random sampling -----
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# Estimated u probabilities using random sampling
#
# Your model is not yet fully trained. Missing estimates for:
#     - city (no m values are trained).
#     - first_name (no m values are trained).
#     - surname (no m values are trained).

# %%
session_person_uid = person_linker.estimate_parameters_using_expectation_maximisation(
    "l.city = r.city")
# Out:
# ----- Starting EM training session -----
#
# Estimating the m probabilities of the model by blocking on:
# l.city = r.city
#
# Parameter estimates will be made for the following comparison(s):
#     - first_name
#     - surname
#
# Parameter estimates cannot be made for the following comparison(s) since they are used in the blocking rules:
#     - city
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# Iteration 1: Largest change in params was -0.25 in the m_probability of first_name, level `Exact match first_name`
# Iteration 2: Largest change in params was -0.0882 in the m_probability of first_name, level `Exact match first_name`
# Iteration 3: Largest change in params was 0.0787 in the m_probability of first_name, level `All other comparisons`
# Iteration 4: Largest change in params was 0.0375 in the m_probability of first_name, level `All other comparisons`
# Iteration 5: Largest change in params was 0.0122 in the m_probability of first_name, level `All other comparisons`
# Iteration 6: Largest change in params was 0.00368 in the m_probability of first_name, level `All other comparisons`
# Iteration 7: Largest change in params was 0.0011 in the m_probability of first_name, level `All other comparisons`
# Iteration 8: Largest change in params was -0.000451 in the m_probability of surname, level `Exact match surname`
# Iteration 9: Largest change in params was 0.000485 in the m_probability of surname, level `All other comparisons`
# Iteration 10: Largest change in params was 0.000524 in the m_probability of surname, level `All other comparisons`
# Iteration 11: Largest change in params was 0.000566 in the m_probability of surname, level `All other comparisons`
# Iteration 12: Largest change in params was 0.000609 in the m_probability of surname, level `All other comparisons`
# Iteration 13: Largest change in params was 0.000655 in the m_probability of surname, level `All other comparisons`
# Iteration 14: Largest change in params was 0.000704 in the m_probability of surname, level `All other comparisons`
# Iteration 15: Largest change in params was 0.000755 in the m_probability of surname, level `All other comparisons`
# Iteration 16: Largest change in params was 0.000809 in the m_probability of surname, level `All other comparisons`
# Iteration 17: Largest change in params was 0.000865 in the m_probability of surname, level `All other comparisons`
# Iteration 18: Largest change in params was 0.000924 in the m_probability of surname, level `All other comparisons`
# Iteration 19: Largest change in params was 0.000984 in the m_probability of surname, level `All other comparisons`
# Iteration 20: Largest change in params was 0.00105 in the m_probability of surname, level `All other comparisons`
# Iteration 21: Largest change in params was 0.00111 in the m_probability of surname, level `All other comparisons`
# Iteration 22: Largest change in params was 0.00118 in the m_probability of surname, level `All other comparisons`
# Iteration 23: Largest change in params was 0.00124 in the m_probability of surname, level `All other comparisons`
# Iteration 24: Largest change in params was 0.00131 in the m_probability of surname, level `All other comparisons`
# Iteration 25: Largest change in params was 0.00138 in the m_probability of surname, level `All other comparisons`
#
# EM converged after 25 iterations
#
# Your model is not yet fully trained. Missing estimates for:
#     - city (no m values are trained).

# %%
session_person_fsn = person_linker.estimate_parameters_using_expectation_maximisation(
    "l.first_name = r.first_name and l.surname = r.surname")
# Out:
# ----- Starting EM training session -----
#
# Estimating the m probabilities of the model by blocking on:
# l.first_name = r.first_name and l.surname = r.surname
#
# Parameter estimates will be made for the following comparison(s):
#     - city
#
# Parameter estimates cannot be made for the following comparison(s) since they are used in the blocking rules:
#     - first_name
#     - surname
#
# Iteration 1: Largest change in params was -0.199 in probability_two_random_records_match
# Iteration 2: Largest change in params was -0.0281 in probability_two_random_records_match
# Iteration 3: Largest change in params was -0.00403 in probability_two_random_records_match
# Iteration 4: Largest change in params was -0.000579 in probability_two_random_records_match
# Iteration 5: Largest change in params was -8.34e-05 in probability_two_random_records_match
#
# EM converged after 5 iterations
#
# Your model is fully trained. All comparisons have at least one estimate for their m and u values

# %%
session_person_fulln = person_linker.estimate_parameters_using_expectation_maximisation(
    "l.full_name  = r.full_name ")
# Out:
# ----- Starting EM training session -----
#
# Estimating the m probabilities of the model by blocking on:
# l.full_name  = r.full_name
#
# Parameter estimates will be made for the following comparison(s):
#     - city
#     - first_name
#     - surname
#
# Parameter estimates cannot be made for the following comparison(s) since they are used in the blocking rules:
#
# WARNING:
# Level Damerau_levenshtein <= 1 on comparison first_name not observed in dataset, unable to train m value
#
# WARNING:
# Level Jaro_winkler_similarity >= 0.9 on comparison first_name not observed in dataset, unable to train m value
#
# WARNING:
# Level Jaro_winkler_similarity >= 0.8 on comparison first_name not observed in dataset, unable to train m value
#
# WARNING:
# Level All other comparisons on comparison first_name not observed in dataset, unable to train m value
#
# WARNING:
# Level Damerau_levenshtein <= 1 on comparison surname not observed in dataset, unable to train m value
#
# WARNING:
# Level Jaro_winkler_similarity >= 0.9 on comparison surname not observed in dataset, unable to train m value
#
# WARNING:
# Level Jaro_winkler_similarity >= 0.8 on comparison surname not observed in dataset, unable to train m value
#
# WARNING:
# Level All other comparisons on comparison surname not observed in dataset, unable to train m value
#
# Iteration 1: Largest change in params was 0.595 in probability_two_random_records_match
# Iteration 2: Largest change in params was 0.387 in probability_two_random_records_match
# Iteration 3: Largest change in params was 0.0172 in probability_two_random_records_match
# Iteration 4: Largest change in params was 9.73e-05 in probability_two_random_records_match
#
# EM converged after 4 iterations
# m probability not trained for first_name - Damerau_levenshtein <= 1 (comparison vector value: 3). This usually means the comparison level was never observed in the training data.
# m probability not trained for first_name - Jaro_winkler_similarity >= 0.9 (comparison vector value: 2). This usually means the comparison level was never observed in the training data.
# m probability not trained for first_name - Jaro_winkler_similarity >= 0.8 (comparison vector value: 1). This usually means the comparison level was never observed in the training data.
# m probability not trained for first_name - All other comparisons (comparison vector value: 0). This usually means the comparison level was never observed in the training data.
# m probability not trained for surname - Damerau_levenshtein <= 1 (comparison vector value: 3). This usually means the comparison level was never observed in the training data.
# m probability not trained for surname - Jaro_winkler_similarity >= 0.9 (comparison vector value: 2). This usually means the comparison level was never observed in the training data.
# m probability not trained for surname - Jaro_winkler_similarity >= 0.8 (comparison vector value: 1). This usually means the comparison level was never observed in the training data.
# m probability not trained for surname - All other comparisons (comparison vector value: 0). This usually means the comparison level was never observed in the training data.
#
# Your model is fully trained. All comparisons have at least one estimate for their m and u values

# %% [markdown]
# Review the parameters
# --

# %%
person_linker.match_weights_chart()
# Out:
# alt.VConcatChart(...)

# %%
person_linker.parameter_estimate_comparisons_chart()
# Out:
# alt.Chart(...)

# %%
person_linker.unlinkables_chart()
# Out:
# alt.LayerChart(...)

# %% [markdown]
# Linkage & deduplication
# --

# %%
# Match probability threshold
# See the unlinkables chart above to determine a good value for this threshold, 
# and the match probabilities below for added context
person_match_threshold = 0.99

person_match_results = person_linker.predict(threshold_match_probability=person_match_threshold) 
person_match = person_match_results.as_pandas_dataframe()
person_match.sample(10)
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
#        match_weight  match_probability   unique_id_l   unique_id_r  \
# 37873      8.448621           0.997146  Q17627027-13   Q17627027-9
# 4884       8.448621           0.997146   Q75705682-1   Q75705682-8
# 32331      8.448621           0.997146     Q538999-2     Q538999-3
# 3940       7.592126           0.994844   Q2585321-15    Q2585321-8
# 10074      8.448621           0.997146   Q21456207-1  Q21456207-15
# 30201      8.448621           0.997146   Q16832027-1   Q16832027-5
# 7970       8.448621           0.997146   Q20733457-2   Q20733457-6
# 18299      8.448621           0.997146   Q81207821-3   Q81207821-4
# 1627       7.260562           0.993521    Q3526667-2    Q3526667-3
# 7189       8.448621           0.997146  Q18810722-10   Q18810722-5
#
#                     city_l               city_r  gamma_city     bf_city  \
# 37873              reading              reading           1  149.071901
# 4884             hertsmere            hertsmere           1  149.071901
# 32331            aldingham            aldingham           1  149.071901
# 3940             yorkshire            yorkshire           1  149.071901
# 10074   kingston upon hull   kingston upon hull           1  149.071901
# 30201               bexley               bexley           1  149.071901
# 7970   newark and sherwood  newark and sherwood           1  149.071901
# 18299        west midlands        west midlands           1  149.071901
# 1627             wakefield            wakefield           1  149.071901
# 7189             islington            islington           1  149.071901
#
#       first_name_l first_name_r  gamma_first_name  bf_first_name  \
# 37873       martin       martin                 4      58.559164
# 4884     frederick    frederick                 4      58.559164
# 32331     reginald     reginald                 4      58.559164
# 3940         zmith        smith                 3      32.341796
# 10074       edward       edward                 4      58.559164
# 30201       violet       violet                 4      58.559164
# 7970          john         john                 4      58.559164
# 18299     georgina     georgina                 4      58.559164
# 1627     théophile   theophilus                 1      25.701209
# 7189     frederick    frederick                 4      58.559164
#
#           surname_l     surname_r  gamma_surname   bf_surname postcode_l  \
# 37873        ridley        ridley              4  1061.913096    rg1 5bn
# 4884        minchin       minchin              4  1061.913096   wd23 4gt
# 32331     blomfield     blomfield              4  1061.913096   la12 9ry
# 3940   wigglesworth  wigglesworth              4  1061.913096   yo31 8jl
# 10074       redmore       redmore              4  1061.913096    hu2 9pb
# 30201      melnotte      melnotte              4  1061.913096    da8 3ay
# 7970         hughes        hughes              4  1061.913096   ng24 3wz
# 18299     aubinière     aubinière              4  1061.913096    dy7 5lj
# 1627           lobb          lobb              4  1061.913096    wf7 6lb
# 7189       goulding      goulding              4  1061.913096     n4 4at
#
#       postcode_r
# 37873    rg1 5bn
# 4884    wd23 4gt
# 32331   la12 9ry
# 3940    yo31 8jl
# 10074    hu2 9pb
# 30201    da8 3ay
# 7970    ng24 3wz
# 18299    dy7 5lj
# 1627     wf7 6lb
# 7189      n4 4at

# %%
len(person_match)
# Out:
# 43412

# %%
person_match.sort_values(by='match_probability', ascending=True).head(15)
# Out:
#        match_weight  match_probability   unique_id_l   unique_id_r  \
# 0          6.910146           0.991754   Q2296770-10   Q2296770-11
# 10597      6.910146           0.991754   Q21460055-3   Q21460055-6
# 10593      6.910146           0.991754   Q18734711-3   Q18734711-7
# 10591      6.910146           0.991754   Q7879758-15   Q7879758-16
# 10590      6.910146           0.991754   Q7879758-15    Q7879758-9
# 10580      6.910146           0.991754   Q15485597-1   Q15485597-9
# 10560      6.910146           0.991754    Q3809493-1    Q3809493-3
# 35842      6.910146           0.991754    Q563069-14     Q563069-3
# 35843      6.910146           0.991754    Q563069-14     Q563069-9
# 10548      6.910146           0.991754    Q3431381-5    Q3431381-6
# 35849      6.910146           0.991754    Q4795441-1    Q4795441-8
# 10598      6.910146           0.991754   Q21460055-3   Q21460055-9
# 35851      6.910146           0.991754  Q16227492-12  Q16227492-19
# 35872      6.910146           0.991754   Q15486486-4   Q15486486-8
# 10505      6.910146           0.991754    Q5930147-1    Q5930147-9
#
#                          city_l                    city_r  gamma_city  \
# 0                         devon                     devon           1
# 10597             pembrokeshire             pembrokeshire           1
# 10593                    dorset                    dorset           1
# 10591       vale of white horse       vale of white horse           1
# 10590       vale of white horse       vale of white horse           1
# 10580                 wakefield                 wakefield           1
# 10560                flintshire                flintshire           1
# 35842                anstruther                anstruther           1
# 35843                anstruther                anstruther           1
# 10548  herefordshire, county of  herefordshire, county of           1
# 35849                     devon                     devon           1
# 10598             pembrokeshire             pembrokeshire           1
# 35851                    camden                    camden           1
# 35872            burton latimer            burton latimer           1
# 10505                   lambeth                   lambeth           1
#
#           bf_city first_name_l first_name_r  gamma_first_name  bf_first_name  \
# 0      149.071901       thomas       thomas                 4      58.559164
# 10597  149.071901       thomas       thomas                 4      58.559164
# 10593  149.071901       samuel       samuel                 4      58.559164
# 10591  149.071901       ulpian       ulpian                 4      58.559164
# 10590  149.071901       ulpian       ulpian                 4      58.559164
# 10580  149.071901     holliday     holliday                 4      58.559164
# 10560  149.071901         john         john                 4      58.559164
# 35842  149.071901       thomas       thomas                 4      58.559164
# 35843  149.071901       thomas       thomas                 4      58.559164
# 10548  149.071901      richard      richard                 4      58.559164
# 35849  149.071901      arnulph      arnulph                 4      58.559164
# 10598  149.071901       thomas       thomas                 4      58.559164
# 35851  149.071901        maria        maria                 4      58.559164
# 35872  149.071901     humphrey     humphrey                 4      58.559164
# 10505  149.071901         hugh         hugh                 4      58.559164
#
#         surname_l  surname_r  gamma_surname  bf_surname postcode_l postcode_r
# 0       chudleigh  chydleigh              3  365.562651   tq13 8jr   tq13 8jr
# 10597      butl4r     butler              3  365.562651   sa43 3gf   sa43 3gf
# 10593  macpherson  mcpherson              3  365.562651    dt4 9ry    dt4 9ry
# 10591     ful2ell    fulwell              3  365.562651    sn7 7eh    sn7 7eh
# 10590     ful2ell    fulwell              3  365.562651    sn7 7eh    sn7 7eh
# 10580     kendall     kendal              3  365.562651    wf1 5dl    wf1 5dl
# 10560      milton     milyon              3  365.562651   ll12 9ru   ll12 9ru
# 35842    chalners   chalmers              3  365.562651   ky10 3ju   ky10 3ju
# 35843    chalners   chalmers              3  365.562651   ky10 3ju   ky10 3ju
# 10548    villakil   villamil              3  365.562651   wr13 6dp   wr13 6dp
# 35849     mallock    maolock              3  365.562651   tq13 8pt   tq13 8pt
# 10598      butl4r     butler              3  365.562651   sa43 3gf   sa43 3gf
# 35851       gibbs      hibbs              3  365.562651   wc1n 3al   wc1n 3al
# 35872    henvhman   henchman              3  365.562651   nn15 6fb   nn15 6fb
# 10505   broughton  broughtpn              3  365.562651   sw16 3ax   sw16 3ax

# %% [markdown]
# Inspect the results
# --

# %%
person_linker.waterfall_chart(person_match_results.as_record_dict(limit=20))
# Out:
# alt.LayerChart(...)

# %%
# Comparison viewer
person_linker.comparison_viewer_dashboard(person_match_results, 
                                          "data/interim/entity_resolution-report-scv.html", 
                                          overwrite=True, num_example_rows=20)
IPython.display.IFrame(src="data/interim/entity_resolution-report-scv.html", width="100%", height=1200)
# Out:
#         <iframe
#             width="100%"
#             height="1200"
#             src="data/interim/entity_resolution-report-scv.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# Clusters
# --

# %%
# Lower threshold = larger (more permissive) clusters
cluster_match_threshold = 0.99

person_clusters_result = person_linker.cluster_pairwise_predictions_at_threshold(person_match_results,
                                                                                 threshold_match_probability=cluster_match_threshold)
person_clusters = person_clusters_result.as_pandas_dataframe().\
    sort_values(by=['cluster_id', 'full_name'])
person_clusters.cluster_id.nunique()
# Out:
# Completed iteration 1, root rows count 9
# Completed iteration 2, root rows count 1
# Completed iteration 3, root rows count 0
# 33869

# %%
person_clusters.sort_values(by=['postcode', 'cluster_id']).head(100).tail(20)
# Out:
#         cluster_id   Source    unique_id      city  postcode  \
# 20895  Q7791193-17  Table 4  Q7791193-17  aberdeen  ab24 3bs
# 24666  Q4718978-11  Table 1  Q4718978-11  aberdeen  ab24 3ex
# 1811    Q4718978-1  Table 3   Q4718978-7  aberdeen  ab24 3hd
# 18527   Q4718978-1  Table 1   Q4718978-4  aberdeen  ab24 3hd
# 22191   Q4718978-1  Table 2  Q4718978-10  aberdeen  ab24 3hd
# 24669   Q4718978-1  Table 3   Q4718978-3  aberdeen  ab24 3hd
# 31132   Q4718978-1  Table 2   Q4718978-2  aberdeen  ab24 3hd
# 46692   Q4718978-1  Table 2   Q4718978-1  aberdeen  ab24 3hd
# 46693   Q4718978-1  Table 3   Q4718978-6  aberdeen  ab24 3hd
# 50295  Q4718978-12  Table 4  Q4718978-12      None  ab24 3hd
# 24668  Q4718978-15  Table 2  Q4718978-15  aberdeen  ab24 3hd
# 24671  Q4718978-15  Table 3   Q4718978-8  aberdeen  ab24 3hd
# 24670   Q4718978-5  Table 1   Q4718978-5      None  ab24 3hd
# 24418  Q27654900-1  Table 2  Q27654900-1   glasgow  ab24 3hp
# 35057  Q27654900-1  Table 1  Q27654900-2   glasgow  ab24 3hp
# 47562  Q27654900-3  Table 4  Q27654900-3   glasgow  ab24 3hp
# 31130  Q4718978-13  Table 3  Q4718978-13  aberdeen  ab24 3hp
# 32343  Q15994414-1  Table 2  Q15994414-2  aberdeen  ab24 3lq
# 36226  Q15994414-1  Table 1  Q15994414-1  aberdeen  ab24 3lq
# 10993  Q15994414-3  Table 4  Q15994414-3  aberdeen  ab24 3lq
#
#                      full_name  first_and_surname first_name  surname  \
# 20895       sir thomas jaffrey        sir jaffrey        sir  jaffrey
# 24666         alexander gurdon   alexander gurdon  alexander   gurdon
# 1811          alexander gordon   alexander gordon  alexander   gordon
# 18527         alexander gordon   alexander gordon  alexander   gordon
# 22191         alexander gordon   alexander gordon  alexander   gordon
# 24669         alexander gordon   alexander gordon  alexander   gordon
# 31132         alexander gordon   alexander gordon  alexander   gordon
# 46692         alexander gordon   alexander gordon  alexander   gordon
# 46693         alexander gordon   alexander gordon  alexander   gordon
# 50295             elsie gurdon       elsie gurdon      elsie   gurdon
# 24668             elsie gurdon       elsie gurdon      elsie   gurdon
# 24671             elsie gurdon       elsie gurdon      elsie   gurdon
# 24670         alexander gordon   alexander gordon  alexander   gordon
# 24418  katherine clerk maxwell  katherine maxwell  katherine  maxwell
# 35057  katherine clerk maxwell  katherine maxwell  katherine  maxwell
# 47562          katherine dewar    katherine dewar  katherine    dewar
# 31130         aledander gordon   aledander gordon  aledander   gordon
# 32343    james matthews duncan       james duncan      james   duncan
# 36226    james matthews duncan       james duncan      james   duncan
# 10993             jacob duncan       jacob duncan      jacob   duncan
#
#               dob  gender    cluster
# 20895        None    male   Q7791193
# 24666  1692-01-01    male   Q4718978
# 1811   1692-01-81    male   Q4718978
# 18527  1692-01-01    male   Q4718978
# 22191        None    None   Q4718978
# 24669  1692-01-01    male   Q4718978
# 31132  1692-01-01    male   Q4718978
# 46692  1692-01-01    male   Q4718978
# 46693  1692-01-01    male   Q4718978
# 50295        None    None   Q4718978
# 24668        None    None   Q4718978
# 24671  1692-01-01    male   Q4718978
# 24670  1682-01-01    male   Q4718978
# 24418  1824-01-01  female  Q27654900
# 35057  1824-01-01  female  Q27654900
# 47562  1825-01-01  female  Q27654900
# 31130  1692-01-00    male   Q4718978
# 32343  1826-04-01    male  Q15994414
# 36226  1826-04-01    male  Q15994414
# 10993        None    male  Q15994414

# %%
# The n largest clusters
largest_clusters = person_clusters.groupby('cluster_id').cluster_id.count().rename('count').\
    sort_values(ascending=False).\
    head(20)
largest_clusters.head()
# Out:
# cluster_id
# Q319331-1      15
# Q5548996-1     14
# Q18750552-1    14
# Q75510166-1    13
# Q59549587-1    13
# Name: count, dtype: int64

# %%
# Cluster viewer
person_linker.cluster_studio_dashboard(person_match_results, person_clusters_result, 
                                       "data/interim/entity_resolution-report-cluster_studio.html", 
#                                        cluster_ids=person_clusters.cluster_id,
#                                        cluster_names=list(person_clusters.label),
#                                        sampling_method="by_cluster_size",
#                                        sampling_method="random", 
#                                        sample_size=100, # This doesn't work when sampling by cluster size -- only ever returns 4
                                       overwrite=True)
IPython.display.IFrame(src="data/interim/entity_resolution-report-cluster_studio.html", width="100%", height=1200)
# Out:
#         <iframe
#             width="100%"
#             height="1200"
#             src="data/interim/entity_resolution-report-cluster_studio.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# Export
# --

# %%
person_match.to_csv('data/processed/entity_resolution-edges.csv', index=False)
person_clusters.to_csv('data/processed/entity_resolution-clusters.csv', index=False)
