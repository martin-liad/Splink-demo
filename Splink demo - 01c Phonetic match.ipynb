# %%
# Example of a phonetic match across multiple columns, with blocking.

# %%
import numpy as np
import numbers
import pandas as pd

import phonetics

from splink.duckdb.linker import DuckDBLinker
import splink.duckdb.comparison_library as cl
import splink.duckdb.comparison_template_library as ctl

# %%
import IPython

# %%
import vega

# %% [markdown]
# Setup
# ==

# %% [markdown]
# Vega setup for charts
# --
# Splink uses Vega for inline charts. We need a bit of setup to make sure these are displayed correctly.

# %%
# !jupyter nbextension install --sys-prefix --py vega

# %%
# !jupyter nbextension enable vega --py --sys-prefix
# Out:
# Enabling notebook extension jupyter-vega/extension...
#       - Validating: ok

# %%
# # A minimal example for debugging:
# vega.Vega({
#     "$schema": "https://vega.github.io/schema/vega-lite/v4.json",
#     "data": {
#         "values": [
#             {"a": "A", "b": 28},
#             {"a": "B", "b": 55},
#             {"a": "C", "b": 43},
#         ]
#     },
#     "mark": "bar",
#     "encoding": {
#         "x": {"field": "b", "type": "quantitative"},
#         "y": {"field": "a", "type": "nominal"}
#     }
# })

# %% [markdown]
# Data
# ==

# %% [markdown]
# Tables
# --

# %%
table1 = pd.read_csv('data/interim/table1.csv', dtype=str)
table1.head(2)
# Out:
#     unique_id     city  postcode               full_name first_and_surname  \
# 0  Q2296770-2    devon  tq13 8df     thomas of chudleigh  thomas chudleigh
# 1  Q1443188-1  bristol   bs2 0el  frank edward brightman   frank brightman
#
#   first_name    surname         dob gender   cluster
# 0     thomas  chudleigh  1630-08-01   male  Q2296770
# 1      frank  brightman  1856-06-18   male  Q1443188

# %%
table2 = pd.read_csv('data/interim/table2.csv', dtype=str)
table2.head(2)
# Out:
#     unique_id     city  postcode               full_name first_and_surname  \
# 0  Q2296770-4    devon  tq13 8hu    thomas 1st chudleigh  thomas chudleigh
# 1  Q1443188-2  bristol   bs2 0el  frank edward brightman   frank brightman
#
#   first_name    surname         dob gender   cluster
# 0     thomas  chudleigh  1630-08-01    NaN  Q2296770
# 1      frank  brightman  1856-06-18   male  Q1443188

# %% [markdown]
# Preprocessing
# ==

# %% [markdown]
# Phonetic match
# --

# %%
def is_null(v):
    if v is None:
        return True
    if isinstance(v, numbers.Number):
        return np.isnan(v)
    return False

# %%
# Metaphone (vs Soundex)
def metaphone(s):
    if is_null(s):
        return None
    try:
        return phonetics.metaphone(s)
    except IndexError:
        print(f"Could not transform string: {s}")
        return None

# %%
metaphone('Karen')
# Out:
# 'KRN'

# %%
metaphone('Karin')
# Out:
# 'KRN'

# %%
# Table 1
for col in ['full_name', 'first_and_surname', 'first_name', 'surname']:
    print(col)
    table1[f'{col}_metaphone'] = table1[col].apply(lambda s: metaphone(s))
table1.sample(5)
# Out:
# full_name
# first_and_surname
# first_name
# surname
#          unique_id                   city  postcode  \
# 1771  Q105824571-1               ashfield  ng17 5gu
# 607     Q5718119-2                 london  sw1p 1jw
# 515    Q7328478-10         stoke-on-trent   st2 8lh
# 2235    Q4718588-4                hatcham   se4 2qn
# 1758   Q16551731-1  north east derbyshire   s44 6uz
#
#                                     full_name           first_and_surname  \
# 1771                  richard staunton cahill              richard cahill
# 607                      henry bernard chalon                henry chalon
# 515                               dick pullan                 dick pullan
# 2235               alexander chinnery-haldane  alexander chinnery-haldane
# 1758  elizabeth cecil, countess of devonshire        elizabeth devonshire
#
#      first_name           surname         dob  gender     cluster  \
# 1771    richard            cahill  1827-01-01    male  Q105824571
# 607       henry            chalon  1770-01-01    male    Q5718119
# 515        dick            pullan         NaN    male    Q7328478
# 2235  alexander  chinnery-haldane  1842-08-14    male    Q4718588
# 1758  elizabeth        devonshire  1619-01-01  female   Q16551731
#
#      full_name_metaphone first_and_surname_metaphone first_name_metaphone  \
# 1771        RXRTSTNTNKHL                     RXRTKHL                 RXRT
# 607          HNRPRNRTXLN                      HNRXLN                  HNR
# 515                TKPLN                       TKPLN                   TK
# 2235       ALKSNTRXNRLTN               ALKSNTRXNRLTN              ALKSNTR
# 1758  ALSP0SSLKNTSFTFNXR                  ALSP0TFNXR                ALSP0
#
#      surname_metaphone
# 1771               KHL
# 607                XLN
# 515                PLN
# 2235            XNRLTN
# 1758             TFNXR

# %%
# Table 2
for col in ['full_name', 'first_and_surname', 'first_name', 'surname']:
    print(col)
    table2[f'{col}_metaphone'] = table2[col].apply(lambda s: metaphone(s))
table1.sample(5)
# Out:
# full_name
# first_and_surname
# first_name
# surname
#        unique_id        city  postcode            full_name  \
# 3971  Q2646506-3  birkenhead  ch41 2yr  sir algernon thomas
# 6      Q631006-2   bucharest  ex20 3pz         moses gaster
# 2003  Q8018606-3      howden  dn14 7bg    william somergell
# 482   Q3530860-1      london  wc2r 1ab         tom ricketts
# 1746  Q1702110-2     glasgow    g4 0le          john watson
#
#       first_and_surname first_name    surname         dob gender   cluster  \
# 3971         sir thomas        sir     thomas  1857-08-03   male  Q2646506
# 6          moses gaster      moses     gaster  1856-09-17   male   Q631006
# 2003  william somergell    william  somergell  1860-04-05   male  Q8018606
# 482        tom ricketts        tom   ricketts  1853-01-15   male  Q3530860
# 1746        john watson       john     watson  1847-02-25   male  Q1702110
#
#      full_name_metaphone first_and_surname_metaphone first_name_metaphone  \
# 3971          SRLKRNNTMS                       SRTMS                   SR
# 6                MSSKSTR                     MSSKSTR                  MSS
# 2003            ALMSMRJL                    ALMSMRJL                  ALM
# 482               TMRKTS                      TMRKTS                   TM
# 1746               JNTSN                       JNTSN                   JN
#
#      surname_metaphone
# 3971               TMS
# 6                 KSTR
# 2003             SMRJL
# 482               RKTS
# 1746              ATSN

# %% [markdown]
# Phonetic match
# ==
# Based on https://moj-analytical-services.github.io/splink/demos/examples/duckdb/link_only.html
#
# Linking two tables without deduplication.

# %% [markdown]
# Settings
# --

# %%
person_match_settings = {
    "link_type": "link_only",
    "unique_id_column_name": "unique_id",
    
    # Blocking, for performance
    "blocking_rules_to_generate_predictions": [
        "l.postcode = r.postcode",
    ],
    "comparisons": [
        cl.exact_match("city", term_frequency_adjustments=False),
        
        # Deterministic name match (phonetic)
        cl.exact_match("first_name_metaphone", term_frequency_adjustments=False),
        cl.exact_match("surname_metaphone", term_frequency_adjustments=False),
#         cl.exact_match("full_name_metaphone", term_frequency_adjustments=False),
    ],
    
    # Needed for waterfall charts of results
    "retain_intermediate_calculation_columns": True,
    "retain_matching_columns": True,
}

# %% [markdown]
# Training
# --

# %%
person_linker = DuckDBLinker(
    [table1, table2],
    person_match_settings)

# %%
person_linker.missingness_chart()
# Out:
# alt.LayerChart(...)

# %%
person_linker.estimate_probability_two_random_records_match(
    #  A list of deterministic matching rules that should be designed to admit 
    # very few (none if possible) false positives:
    [
        "l.city = r.city and l.full_name = r.full_name",
    ], 
    recall=0.9)
# Out:
# Probability two random records match is estimated to be  7.9e-05.
# This means that amongst all possible pairwise record comparisons, one in 12,652.24 are expected to match.  With 19,386,048 total possible comparisons, we expect a total of around 1,532.22 matching pairs

# %%
# Estimate U
person_linker.estimate_u_using_random_sampling(max_pairs=1e6, seed=1)
# Out:
# ----- Estimating u probabilities using random sampling -----
#
# Estimated u probabilities using random sampling
#
# Your model is not yet fully trained. Missing estimates for:
#     - city (no m values are trained).
#     - first_name_metaphone (no m values are trained).
#     - surname_metaphone (no m values are trained).

# %%
session_person_uid = person_linker.estimate_parameters_using_expectation_maximisation(
    "l.city = r.city")
# Out:
# ----- Starting EM training session -----
#
# Estimating the m probabilities of the model by blocking on:
# l.city = r.city
#
# Parameter estimates will be made for the following comparison(s):
#     - first_name_metaphone
#     - surname_metaphone
#
# Parameter estimates cannot be made for the following comparison(s) since they are used in the blocking rules:
#     - city
#
# Iteration 1: Largest change in params was -0.0237 in the m_probability of surname_metaphone, level `All other comparisons`
# Iteration 2: Largest change in params was -0.0589 in the m_probability of first_name_metaphone, level `Exact match`
# Iteration 3: Largest change in params was -0.0408 in the m_probability of first_name_metaphone, level `Exact match`
# Iteration 4: Largest change in params was -0.0176 in the m_probability of first_name_metaphone, level `Exact match`
# Iteration 5: Largest change in params was 0.00624 in the m_probability of first_name_metaphone, level `All other comparisons`
# Iteration 6: Largest change in params was -0.00205 in the m_probability of first_name_metaphone, level `Exact match`
# Iteration 7: Largest change in params was 0.000662 in the m_probability of first_name_metaphone, level `All other comparisons`
# Iteration 8: Largest change in params was 0.000212 in the m_probability of first_name_metaphone, level `All other comparisons`
# Iteration 9: Largest change in params was 9.59e-05 in the m_probability of surname_metaphone, level `All other comparisons`
#
# EM converged after 9 iterations
#
# Your model is not yet fully trained. Missing estimates for:
#     - city (no m values are trained).

# %%
session_person_fsn = person_linker.estimate_parameters_using_expectation_maximisation(
    "l.first_name_metaphone = r.first_name_metaphone and l.surname_metaphone = r.surname_metaphone")
# Out:
# ----- Starting EM training session -----
#
# Estimating the m probabilities of the model by blocking on:
# l.first_name_metaphone = r.first_name_metaphone and l.surname_metaphone = r.surname_metaphone
#
# Parameter estimates will be made for the following comparison(s):
#     - city
#
# Parameter estimates cannot be made for the following comparison(s) since they are used in the blocking rules:
#     - first_name_metaphone
#     - surname_metaphone
#
# Iteration 1: Largest change in params was -0.218 in probability_two_random_records_match
# Iteration 2: Largest change in params was -0.014 in probability_two_random_records_match
# Iteration 3: Largest change in params was -0.000986 in probability_two_random_records_match
# Iteration 4: Largest change in params was -7.03e-05 in probability_two_random_records_match
#
# EM converged after 4 iterations
#
# Your model is fully trained. All comparisons have at least one estimate for their m and u values

# %%
session_person_fulln = person_linker.estimate_parameters_using_expectation_maximisation(
    "l.full_name_metaphone  = r.full_name_metaphone")
# Out:
# ----- Starting EM training session -----
#
# Estimating the m probabilities of the model by blocking on:
# l.full_name_metaphone  = r.full_name_metaphone
#
# Parameter estimates will be made for the following comparison(s):
#     - city
#     - first_name_metaphone
#     - surname_metaphone
#
# Parameter estimates cannot be made for the following comparison(s) since they are used in the blocking rules:
#
# Iteration 1: Largest change in params was 0.64 in probability_two_random_records_match
# Iteration 2: Largest change in params was 0.27 in probability_two_random_records_match
# Iteration 3: Largest change in params was 0.0152 in probability_two_random_records_match
# Iteration 4: Largest change in params was 0.0207 in the m_probability of surname_metaphone, level `All other comparisons`
# Iteration 5: Largest change in params was 0.0353 in the m_probability of surname_metaphone, level `All other comparisons`
# Iteration 6: Largest change in params was -0.00781 in the m_probability of surname_metaphone, level `Exact match`
# Iteration 7: Largest change in params was 0.000675 in probability_two_random_records_match
# Iteration 8: Largest change in params was 0.000122 in probability_two_random_records_match
# Iteration 9: Largest change in params was 0.000291 in probability_two_random_records_match
# Iteration 10: Largest change in params was 0.000373 in probability_two_random_records_match
# Iteration 11: Largest change in params was 0.000206 in probability_two_random_records_match
# Iteration 12: Largest change in params was 8.68e-05 in probability_two_random_records_match
#
# EM converged after 12 iterations
#
# Your model is fully trained. All comparisons have at least one estimate for their m and u values

# %% [markdown]
# Review the parameters
# --

# %%
person_linker.match_weights_chart()
# Out:
# alt.VConcatChart(...)

# %%
person_linker.parameter_estimate_comparisons_chart()
# Out:
# alt.Chart(...)

# %%
person_linker.unlinkables_chart()
# Out:
# alt.LayerChart(...)

# %% [markdown]
# Linking
# --

# %%
# Match probability threshold
# See the unlinkables chart above to determine a good value for this threshold, 
# and the match probabilities below for added context
person_match_threshold = 0.99

person_match_results = person_linker.predict(threshold_match_probability=person_match_threshold) 
person_match = person_match_results.as_pandas_dataframe()
person_match.sample(10)
# Out:
#       match_weight  match_probability         source_dataset_l  \
# 997       7.686384           0.995169  __splink__input_table_0
# 16        7.686384           0.995169  __splink__input_table_0
# 439       7.686384           0.995169  __splink__input_table_0
# 1113      7.686384           0.995169  __splink__input_table_0
# 1205      7.686384           0.995169  __splink__input_table_0
# 1260      7.686384           0.995169  __splink__input_table_0
# 1252      7.686384           0.995169  __splink__input_table_0
# 490       7.686384           0.995169  __splink__input_table_0
# 418       7.686384           0.995169  __splink__input_table_0
# 1151      7.686384           0.995169  __splink__input_table_0
#
#              source_dataset_r  unique_id_l   unique_id_r  \
# 997   __splink__input_table_1   Q8013972-1    Q8013972-2
# 16    __splink__input_table_1   Q1391460-4    Q1391460-1
# 439   __splink__input_table_1   Q3108513-2    Q3108513-1
# 1113  __splink__input_table_1   Q4722779-1    Q4722779-3
# 1205  __splink__input_table_1   Q7526494-3    Q7526494-2
# 1260  __splink__input_table_1  Q97801414-5  Q97801414-10
# 1252  __splink__input_table_1  Q50210878-3   Q50210878-4
# 490   __splink__input_table_1  Q28873162-1   Q28873162-3
# 418   __splink__input_table_1    Q613852-5     Q613852-1
# 1151  __splink__input_table_1   Q5342415-2    Q5342415-8
#
#                      city_l                 city_r  gamma_city     bf_city  \
# 997                  barnet                 barnet           1  132.707313
# 16                  focșani                focșani           1  132.707313
# 439   dumfries and galloway  dumfries and galloway           1  132.707313
# 1113                 fulham                 fulham           1  132.707313
# 1205             manchester             manchester           1  132.707313
# 1260                 barnet                 barnet           1  132.707313
# 1252                norwich                norwich           1  132.707313
# 490                  medway                 medway           1  132.707313
# 418                  london                 london           1  132.707313
# 1151              liverpool              liverpool           1  132.707313
#
#      first_name_metaphone_l first_name_metaphone_r  \
# 997                     ALM                    ALM
# 16                     SLMN                   SLMN
# 439                     PTR                    PTR
# 1113                  ALFRT                  ALFRT
# 1205                     SR                     SR
# 1260                     MR                     MR
# 1252                  FRTRK                  FRTRK
# 490                    ATRT                   ATRT
# 418                      JN                     JN
# 1151                   ATRT                   ATRT
#
#       gamma_first_name_metaphone  bf_first_name_metaphone surname_metaphone_l  \
# 997                            1                40.357551                  KR
# 16                             1                40.357551                XKTR
# 439                            1                40.357551                 ART
# 1113                           1                40.357551                HKMN
# 1205                           1                40.357551                PRNT
# 1260                           1                40.357551                 XRP
# 1252                           1                40.357551                 FTT
# 490                            1                40.357551                  AT
# 418                            1                40.357551                KSNS
# 1151                           1                40.357551                  KR
#
#      surname_metaphone_r  gamma_surname_metaphone  bf_surname_metaphone  \
# 997                   KR                        1            486.570282
# 16                  XKTR                        1            486.570282
# 439                  ART                        1            486.570282
# 1113                HKMN                        1            486.570282
# 1205                PRNT                        1            486.570282
# 1260                 XRP                        1            486.570282
# 1252                 FTT                        1            486.570282
# 490                   AT                        1            486.570282
# 418                 KSNS                        1            486.570282
# 1151                  KR                        1            486.570282
#
#      postcode_l postcode_r
# 997     nw7 4jy    nw7 4jy
# 16      b42 2hs    b42 2hs
# 439     dg1 2da    dg1 2da
# 1113   sw15 2ny   sw15 2ny
# 1205    m15 6wj    m15 6wj
# 1260    ha8 8tr    ha8 8tr
# 1252    nr5 8dd    nr5 8dd
# 490     me2 4na    me2 4na
# 418     w1t 2rf    w1t 2rf
# 1151     l3 1qw     l3 1qw

# %%
# Exact match is 1370
len(person_match)
# Out:
# 1429

# %%
person_match.sort_values(by='match_probability', ascending=True).head(15)
# Out:
#      match_weight  match_probability         source_dataset_l  \
# 0        7.686384           0.995169  __splink__input_table_0
# 957      7.686384           0.995169  __splink__input_table_0
# 956      7.686384           0.995169  __splink__input_table_0
# 955      7.686384           0.995169  __splink__input_table_0
# 954      7.686384           0.995169  __splink__input_table_0
# 953      7.686384           0.995169  __splink__input_table_0
# 952      7.686384           0.995169  __splink__input_table_0
# 951      7.686384           0.995169  __splink__input_table_0
# 950      7.686384           0.995169  __splink__input_table_0
# 958      7.686384           0.995169  __splink__input_table_0
# 949      7.686384           0.995169  __splink__input_table_0
# 947      7.686384           0.995169  __splink__input_table_0
# 946      7.686384           0.995169  __splink__input_table_0
# 945      7.686384           0.995169  __splink__input_table_0
# 944      7.686384           0.995169  __splink__input_table_0
#
#             source_dataset_r   unique_id_l   unique_id_r           city_l  \
# 0    __splink__input_table_1    Q1443188-1    Q1443188-2          bristol
# 957  __splink__input_table_1    Q5718316-1    Q5718316-2    hertfordshire
# 956  __splink__input_table_1   Q21455451-4   Q21455451-6  southend-on-sea
# 955  __splink__input_table_1    Q8019371-4    Q8019371-3       tattyreagh
# 954  __splink__input_table_1    Q8004400-3    Q8004400-1          glasgow
# 953  __splink__input_table_1   Q56682735-2   Q56682735-3          reading
# 952  __splink__input_table_1    Q7793299-5    Q7793299-2         scotland
# 951  __splink__input_table_1   Q16023428-1   Q16023428-2         stafford
# 950  __splink__input_table_1  Q105533631-1  Q105533631-4         cornwall
# 958  __splink__input_table_1    Q7526211-4    Q7526211-1       nottingham
# 949  __splink__input_table_1   Q88466477-2   Q88466477-3       st. helens
# 947  __splink__input_table_1    Q7527435-1    Q7527435-3            dover
# 946  __splink__input_table_1   Q18206167-1   Q18206167-2           dudley
# 945  __splink__input_table_1   Q47541460-1   Q47541460-4         tameside
# 944  __splink__input_table_1    Q5660363-2    Q5660363-1         havering
#
#               city_r  gamma_city     bf_city first_name_metaphone_l  \
# 0            bristol           1  132.707313                   FRNK
# 957    hertfordshire           1  132.707313                    HNR
# 956  southend-on-sea           1  132.707313                    ASK
# 955       tattyreagh           1  132.707313                    ALM
# 954          glasgow           1  132.707313                    ALM
# 953          reading           1  132.707313                      H
# 952         scotland           1  132.707313                    TMS
# 951         stafford           1  132.707313                  FRTRK
# 950         cornwall           1  132.707313                    HNR
# 958       nottingham           1  132.707313                     SR
# 949       st. helens           1  132.707313                     AM
# 947            dover           1  132.707313                     SR
# 946           dudley           1  132.707313                    TMS
# 945         tameside           1  132.707313                    JMS
# 944         havering           1  132.707313                   HRLT
#
#     first_name_metaphone_r  gamma_first_name_metaphone  \
# 0                     FRNK                           1
# 957                    HNR                           1
# 956                    ASK                           1
# 955                    ALM                           1
# 954                    ALM                           1
# 953                      H                           1
# 952                    TMS                           1
# 951                  FRTRK                           1
# 950                    HNR                           1
# 958                     SR                           1
# 949                     AM                           1
# 947                     SR                           1
# 946                    TMS                           1
# 945                    JMS                           1
# 944                   HRLT                           1
#
#      bf_first_name_metaphone surname_metaphone_l surname_metaphone_r  \
# 0                  40.357551               PRTMN               PRTMN
# 957                40.357551                PLNT                PLNT
# 956                40.357551                 KLN                 KLN
# 955                40.357551               TMPSN               TMPSN
# 954                40.357551              ANTRSN              ANTRSN
# 953                40.357551                PRJS                PRJS
# 952                40.357551               PRNKL               PRNKL
# 951                40.357551                KPNS                KPNS
# 950                40.357551                ARNT                ARNT
# 958                40.357551                PRNT                PRNT
# 949                40.357551                PRRL                PRRL
# 947                40.357551                PRNT                PRNT
# 946                40.357551               KRRST               KRRST
# 945                40.357551                ALSN                ALSN
# 944                40.357551                 KKS                 KKS
#
#      gamma_surname_metaphone  bf_surname_metaphone postcode_l postcode_r
# 0                          1            486.570282    bs2 0el    bs2 0el
# 957                        1            486.570282    sg1 2da    sg1 2da
# 956                        1            486.570282    ss9 4js    ss9 4js
# 955                        1            486.570282   bt78 2eg   bt78 2eg
# 954                        1            486.570282     g1 1nq     g1 1nq
# 953                        1            486.570282    rg4 7tf    rg4 7tf
# 952                        1            486.570282   ip31 3el   ip31 3el
# 951                        1            486.570282   st15 0lj   st15 0lj
# 950                        1            486.570282   pl24 2rw   pl24 2rw
# 958                        1            486.570282    ng1 5hr    ng1 5hr
# 949                        1            486.570282    wa9 5dt    wa9 5dt
# 947                        1            486.570282    ct3 3hl    ct3 3hl
# 946                        1            486.570282    dy1 2hl    dy1 2hl
# 945                        1            486.570282   sk14 5qz   sk14 5qz
# 944                        1            486.570282   rm12 5jt   rm12 5jt

# %%
person_match.match_weight.value_counts()
# Out:
# match_weight
# 7.686384    1429
# Name: count, dtype: int64

# %%
person_match.match_probability.value_counts()
# Out:
# match_probability
# 0.995169    1429
# Name: count, dtype: int64

# %% [markdown]
# Inspect the results
# --

# %%
person_linker.waterfall_chart(person_match_results.as_record_dict(limit=20))
# Out:
# alt.LayerChart(...)

# %%
# Comparison viewer
person_linker.comparison_viewer_dashboard(person_match_results, 
                                          "data/interim/person_match-phonetic-report-scv.html", 
                                          overwrite=True, num_example_rows=20)
IPython.display.IFrame(src="data/interim/person_match-phonetic-report-scv.html", width="100%", height=1200)
# Out:
#         <iframe
#             width="100%"
#             height="1200"
#             src="data/interim/person_match-phonetic-report-scv.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# Export
# --

# %%
person_match.to_csv('data/processed/person_match-phonetic.csv', index=False)
