# %%
# Example of a fuzzy match across multiple columns, with blocking.

# %%
import numpy as np
import numbers
import pandas as pd

import phonetics

from splink.duckdb.linker import DuckDBLinker
import splink.duckdb.comparison_library as cl
import splink.duckdb.comparison_template_library as ctl

# %%
import IPython

# %%
import vega

# %% [markdown]
# Setup
# ==

# %% [markdown]
# Vega setup for charts
# --
# Splink uses Vega for inline charts. We need a bit of setup to make sure these are displayed correctly.

# %%
# !jupyter nbextension install --sys-prefix --py vega

# %%
# !jupyter nbextension enable vega --py --sys-prefix
# Out:
# Enabling notebook extension jupyter-vega/extension...
#       - Validating: ok

# %%
# # A minimal example for debugging:
# vega.Vega({
#     "$schema": "https://vega.github.io/schema/vega-lite/v4.json",
#     "data": {
#         "values": [
#             {"a": "A", "b": 28},
#             {"a": "B", "b": 55},
#             {"a": "C", "b": 43},
#         ]
#     },
#     "mark": "bar",
#     "encoding": {
#         "x": {"field": "b", "type": "quantitative"},
#         "y": {"field": "a", "type": "nominal"}
#     }
# })

# %% [markdown]
# Data
# ==

# %% [markdown]
# Tables
# --

# %%
table1 = pd.read_csv('data/interim/table1.csv', dtype=str)
table1.head(2)
# Out:
#     unique_id     city  postcode               full_name first_and_surname  \
# 0  Q2296770-2    devon  tq13 8df     thomas of chudleigh  thomas chudleigh
# 1  Q1443188-1  bristol   bs2 0el  frank edward brightman   frank brightman
#
#   first_name    surname         dob gender   cluster
# 0     thomas  chudleigh  1630-08-01   male  Q2296770
# 1      frank  brightman  1856-06-18   male  Q1443188

# %%
table2 = pd.read_csv('data/interim/table2.csv', dtype=str)
table2.head(2)
# Out:
#     unique_id     city  postcode               full_name first_and_surname  \
# 0  Q2296770-4    devon  tq13 8hu    thomas 1st chudleigh  thomas chudleigh
# 1  Q1443188-2  bristol   bs2 0el  frank edward brightman   frank brightman
#
#   first_name    surname         dob gender   cluster
# 0     thomas  chudleigh  1630-08-01    NaN  Q2296770
# 1      frank  brightman  1856-06-18   male  Q1443188

# %% [markdown]
# Fuzzy match
# ==
# Based on https://moj-analytical-services.github.io/splink/demos/examples/duckdb/link_only.html
#
# Linking two tables without deduplication.

# %% [markdown]
# Settings
# --

# %%
person_match_settings = {
    "link_type": "link_only",
    "unique_id_column_name": "unique_id",
    
    # Blocking, for performance
    "blocking_rules_to_generate_predictions": [
        "l.postcode = r.postcode",
    ],
    "comparisons": [
        cl.exact_match("city", term_frequency_adjustments=False),
        
        # Probabilistic name match (string distances)
        
        # For documentation of the name comparators used here, see:
        # https://moj-analytical-services.github.io/splink/comparison_template_library.html
        
        # For advice on choosing good thresholds see: 
        # https://moj-analytical-services.github.io/splink/topic_guides/comparisons/choosing_comparators.html
        
        ctl.name_comparison("first_name"), 
#         ctl.name_comparison("first_name", 
#                             term_frequency_adjustments=False,
#                             levenshtein_thresholds=[1],         # No. of single-char insert/delete/subst
#                             damerau_levenshtein_thresholds=[],  # ... or 2-char transpose
#                             jaro_thresholds=[],                 # Character occurrences regardless of order
#                             jaro_winkler_thresholds=[],         # ... with preference for beginning of string
#                             jaccard_thresholds=[]),
        ctl.name_comparison("surname"), 
#         ctl.name_comparison("full_name"), 

#         ctl.forename_surname_comparison("first_name", "surname"),
#         ctl.forename_surname_comparison("first_name", "surname",
#                                         term_frequency_adjustments=False,
#                                         include_columns_reversed=False,
#                                         levenshtein_thresholds=[],
#                                         damerau_levenshtein_thresholds=[], 
#                                         jaro_thresholds=[], 
#                                         jaro_winkler_thresholds=[0.88], 
#                                         jaccard_thresholds=[]),
    ],
    
    # Needed for waterfall charts of results
    "retain_intermediate_calculation_columns": True,
    "retain_matching_columns": True,
}

# %% [markdown]
# Training
# --

# %%
person_linker = DuckDBLinker(
    [table1, table2],
    person_match_settings)

# %%
person_linker.missingness_chart()
# Out:
# alt.LayerChart(...)

# %%
person_linker.estimate_probability_two_random_records_match(
    #  A list of deterministic matching rules that should be designed to admit 
    # very few (none if possible) false positives:
    [
        "l.city = r.city and l.full_name = r.full_name",
    ], 
    recall=0.9)
# Out:
# Probability two random records match is estimated to be  7.9e-05.
# This means that amongst all possible pairwise record comparisons, one in 12,652.24 are expected to match.  With 19,386,048 total possible comparisons, we expect a total of around 1,532.22 matching pairs

# %%
# Estimate U
person_linker.estimate_u_using_random_sampling(max_pairs=1e6, seed=1)
# Out:
# ----- Estimating u probabilities using random sampling -----
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# Estimated u probabilities using random sampling
#
# Your model is not yet fully trained. Missing estimates for:
#     - city (no m values are trained).
#     - first_name (no m values are trained).
#     - surname (no m values are trained).

# %%
session_person_uid = person_linker.estimate_parameters_using_expectation_maximisation(
    "l.city = r.city")
# Out:
# ----- Starting EM training session -----
#
# Estimating the m probabilities of the model by blocking on:
# l.city = r.city
#
# Parameter estimates will be made for the following comparison(s):
#     - first_name
#     - surname
#
# Parameter estimates cannot be made for the following comparison(s) since they are used in the blocking rules:
#     - city
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# Iteration 1: Largest change in params was -0.11 in the m_probability of first_name, level `Exact match first_name`
# Iteration 2: Largest change in params was -0.033 in the m_probability of first_name, level `Exact match first_name`
# Iteration 3: Largest change in params was 0.0244 in the m_probability of first_name, level `All other comparisons`
# Iteration 4: Largest change in params was 0.0165 in the m_probability of first_name, level `All other comparisons`
# Iteration 5: Largest change in params was 0.0079 in the m_probability of first_name, level `All other comparisons`
# Iteration 6: Largest change in params was 0.00324 in the m_probability of first_name, level `All other comparisons`
# Iteration 7: Largest change in params was 0.00126 in the m_probability of first_name, level `All other comparisons`
# Iteration 8: Largest change in params was 0.000475 in the m_probability of first_name, level `All other comparisons`
# Iteration 9: Largest change in params was 0.000179 in the m_probability of first_name, level `All other comparisons`
# Iteration 10: Largest change in params was -0.000104 in the m_probability of surname, level `Exact match surname`
# Iteration 11: Largest change in params was 9.81e-05 in the m_probability of surname, level `All other comparisons`
#
# EM converged after 11 iterations
#
# Your model is not yet fully trained. Missing estimates for:
#     - city (no m values are trained).

# %%
session_person_fsn = person_linker.estimate_parameters_using_expectation_maximisation(
    "l.first_name = r.first_name and l.surname = r.surname")
# Out:
# ----- Starting EM training session -----
#
# Estimating the m probabilities of the model by blocking on:
# l.first_name = r.first_name and l.surname = r.surname
#
# Parameter estimates will be made for the following comparison(s):
#     - city
#
# Parameter estimates cannot be made for the following comparison(s) since they are used in the blocking rules:
#     - first_name
#     - surname
#
# Iteration 1: Largest change in params was -0.328 in probability_two_random_records_match
# Iteration 2: Largest change in params was -0.0165 in the m_probability of city, level `Exact match`
# Iteration 3: Largest change in params was 0.000963 in the m_probability of city, level `All other comparisons`
# Iteration 4: Largest change in params was 5.46e-05 in the m_probability of city, level `All other comparisons`
#
# EM converged after 4 iterations
#
# Your model is fully trained. All comparisons have at least one estimate for their m and u values

# %%
session_person_fulln = person_linker.estimate_parameters_using_expectation_maximisation(
    "l.full_name  = r.full_name ")
# Out:
# ----- Starting EM training session -----
#
# Estimating the m probabilities of the model by blocking on:
# l.full_name  = r.full_name
#
# Parameter estimates will be made for the following comparison(s):
#     - city
#     - first_name
#     - surname
#
# Parameter estimates cannot be made for the following comparison(s) since they are used in the blocking rules:
#
# WARNING:
# Level Damerau_levenshtein <= 1 on comparison first_name not observed in dataset, unable to train m value
#
# WARNING:
# Level Jaro_winkler_similarity >= 0.9 on comparison first_name not observed in dataset, unable to train m value
#
# WARNING:
# Level Jaro_winkler_similarity >= 0.8 on comparison first_name not observed in dataset, unable to train m value
#
# WARNING:
# Level All other comparisons on comparison first_name not observed in dataset, unable to train m value
#
# WARNING:
# Level Damerau_levenshtein <= 1 on comparison surname not observed in dataset, unable to train m value
#
# WARNING:
# Level Jaro_winkler_similarity >= 0.9 on comparison surname not observed in dataset, unable to train m value
#
# WARNING:
# Level Jaro_winkler_similarity >= 0.8 on comparison surname not observed in dataset, unable to train m value
#
# WARNING:
# Level All other comparisons on comparison surname not observed in dataset, unable to train m value
#
# Iteration 1: Largest change in params was 0.826 in probability_two_random_records_match
# Iteration 2: Largest change in params was 0.172 in probability_two_random_records_match
# Iteration 3: Largest change in params was 0.00227 in probability_two_random_records_match
# Iteration 4: Largest change in params was 1.06e-05 in probability_two_random_records_match
#
# EM converged after 4 iterations
# m probability not trained for first_name - Damerau_levenshtein <= 1 (comparison vector value: 3). This usually means the comparison level was never observed in the training data.
# m probability not trained for first_name - Jaro_winkler_similarity >= 0.9 (comparison vector value: 2). This usually means the comparison level was never observed in the training data.
# m probability not trained for first_name - Jaro_winkler_similarity >= 0.8 (comparison vector value: 1). This usually means the comparison level was never observed in the training data.
# m probability not trained for first_name - All other comparisons (comparison vector value: 0). This usually means the comparison level was never observed in the training data.
# m probability not trained for surname - Damerau_levenshtein <= 1 (comparison vector value: 3). This usually means the comparison level was never observed in the training data.
# m probability not trained for surname - Jaro_winkler_similarity >= 0.9 (comparison vector value: 2). This usually means the comparison level was never observed in the training data.
# m probability not trained for surname - Jaro_winkler_similarity >= 0.8 (comparison vector value: 1). This usually means the comparison level was never observed in the training data.
# m probability not trained for surname - All other comparisons (comparison vector value: 0). This usually means the comparison level was never observed in the training data.
#
# Your model is fully trained. All comparisons have at least one estimate for their m and u values

# %% [markdown]
# Review the parameters
# --

# %%
person_linker.match_weights_chart()
# Out:
# alt.VConcatChart(...)

# %%
person_linker.parameter_estimate_comparisons_chart()
# Out:
# alt.Chart(...)

# %%
person_linker.unlinkables_chart()
# Out:
# alt.LayerChart(...)

# %% [markdown]
# Linking
# --

# %%
# Match probability threshold
# See the unlinkables chart above to determine a good value for this threshold, 
# and the match probabilities below for added context
person_match_threshold = 0.99

person_match_results = person_linker.predict(threshold_match_probability=person_match_threshold) 
person_match = person_match_results.as_pandas_dataframe()
person_match.sample(10)
# Out:
#       match_weight  match_probability         source_dataset_l  \
# 713       7.625249           0.994961  __splink__input_table_0
# 273       8.933053           0.997958  __splink__input_table_0
# 514       8.933053           0.997958  __splink__input_table_0
# 703       8.933053           0.997958  __splink__input_table_0
# 449       8.933053           0.997958  __splink__input_table_0
# 1419      8.933053           0.997958  __splink__input_table_0
# 125       8.933053           0.997958  __splink__input_table_0
# 1371      8.933053           0.997958  __splink__input_table_0
# 1527      8.933053           0.997958  __splink__input_table_0
# 828       8.933053           0.997958  __splink__input_table_0
#
#              source_dataset_r  unique_id_l  unique_id_r  \
# 713   __splink__input_table_1  Q28037657-4  Q28037657-3
# 273   __splink__input_table_1   Q3401572-2   Q3401572-1
# 514   __splink__input_table_1   Q6139106-2   Q6139106-1
# 703   __splink__input_table_1  Q21453621-1  Q21453621-2
# 449   __splink__input_table_1   Q5536979-1   Q5536979-2
# 1419  __splink__input_table_1   Q2741203-2   Q2741203-1
# 125   __splink__input_table_1    Q711325-1    Q711325-2
# 1371  __splink__input_table_1   Q4529867-1   Q4529867-2
# 1527  __splink__input_table_1  Q76847659-2  Q76847659-1
# 828   __splink__input_table_1  Q55720024-1  Q55720024-2
#
#                              city_l                         city_r  \
# 713                      colchester                     colchester
# 273                  plas penmynydd                 plas penmynydd
# 514                     scarborough                    scarborough
# 703                        cherwell                       cherwell
# 449                       blackpool                      blackpool
# 1419  east saltoun and west saltoun  east saltoun and west saltoun
# 125                       leicester                      leicester
# 1371                         london                         london
# 1527                         exeter                         exeter
# 828                         walsall                        walsall
#
#       gamma_city     bf_city first_name_l first_name_r  gamma_first_name  \
# 713            1  136.108258      charles         carl                 1
# 273            1  136.108258       robert       robert                 4
# 514            1  136.108258        james        james                 4
# 703            1  136.108258        henry        henry                 4
# 449            1  136.108258       george       george                 4
# 1419           1  136.108258         john         john                 4
# 125            1  136.108258       arthur       arthur                 4
# 1371           1  136.108258       julian       julian                 4
# 1527           1  136.108258      william      william                 4
# 828            1  136.108258        susan        susan                 4
#
#       bf_first_name surname_l surname_r  gamma_surname   bf_surname  \
# 713       18.186183  marshall  marshall              4  1009.103537
# 273       45.022541       huw       huw              4  1009.103537
# 514       45.022541    wilson    wilson              4  1009.103537
# 703       45.022541    dawson    dawson              4  1009.103537
# 449       45.022541      bigg      bigg              4  1009.103537
# 1419      45.022541   thomson   thomson              4  1009.103537
# 125       45.022541    newman    newman              4  1009.103537
# 1371      45.022541   egerton   egerton              4  1009.103537
# 1527      45.022541     lloyd     lloyd              4  1009.103537
# 828       45.022541    mcbeth    mcbeth              4  1009.103537
#
#      postcode_l postcode_r
# 713     co4 5hp    co4 5hp
# 273    sa19 9uw   sa19 9uw
# 514    yo14 9bl   yo14 9bl
# 703    ox16 3jj   ox16 3jj
# 449     fy4 4nj    fy4 4nj
# 1419   eh34 5eb   eh34 5eb
# 125     le5 3gg    le5 3gg
# 1371   se11 6qu   se11 6qu
# 1527    ex3 0an    ex3 0an
# 828     ws3 5ey    ws3 5ey

# %%
# Exact match = 1370
len(person_match)
# Out:
# 1585

# %%
person_match.sort_values(by='match_probability', ascending=True).head(15)
# Out:
#       match_weight  match_probability         source_dataset_l  \
# 1006      6.666203            0.99025  __splink__input_table_0
# 1209      6.666203            0.99025  __splink__input_table_0
# 393       6.666203            0.99025  __splink__input_table_0
# 37        6.666203            0.99025  __splink__input_table_0
# 38        6.666203            0.99025  __splink__input_table_0
# 570       6.666203            0.99025  __splink__input_table_0
# 446       6.666203            0.99025  __splink__input_table_0
# 948       6.666203            0.99025  __splink__input_table_0
# 952       6.666203            0.99025  __splink__input_table_0
# 738       6.666203            0.99025  __splink__input_table_0
# 328       6.666203            0.99025  __splink__input_table_0
# 577       6.666203            0.99025  __splink__input_table_0
# 964       6.666203            0.99025  __splink__input_table_0
# 584       6.666203            0.99025  __splink__input_table_0
# 967       6.666203            0.99025  __splink__input_table_0
#
#              source_dataset_r  unique_id_l  unique_id_r         city_l  \
# 1006  __splink__input_table_1  Q4821397-11   Q4821397-1          dover
# 1209  __splink__input_table_1   Q7817912-9   Q7817912-1       scotland
# 393   __splink__input_table_1  Q26722118-3  Q26722118-5     st. helens
# 37    __splink__input_table_1   Q5236742-2   Q5236742-1         gdańsk
# 38    __splink__input_table_1  Q19585833-1  Q19585833-2         mendip
# 570   __splink__input_table_1  Q14623866-4  Q14623866-3  south norfolk
# 446   __splink__input_table_1  Q12353681-2  Q12353681-5       lewisham
# 948   __splink__input_table_1  Q65665593-1  Q65665593-4          lewes
# 952   __splink__input_table_1   Q5414294-7   Q5414294-5         exeter
# 738   __splink__input_table_1   Q6929970-1   Q6929970-4       cotswold
# 328   __splink__input_table_1   Q4867177-1   Q4867177-3  wolverhampton
# 577   __splink__input_table_1   Q5345861-2   Q5345861-7         london
# 964   __splink__input_table_1   Q6234556-1   Q6234556-3     sunderland
# 584   __splink__input_table_1  Q60772340-1  Q60772340-3        glasgow
# 967   __splink__input_table_1    Q541198-3    Q541198-2         dublin
#
#              city_r  gamma_city     bf_city first_name_l first_name_r  \
# 1006          dover           1  136.108258     augustus     augustus
# 1209       scotland           1  136.108258          tom          tom
# 393      st. helens           1  136.108258    justinian    justinian
# 37           gdańsk           1  136.108258        david        david
# 38           mendip           1  136.108258         john         john
# 570   south norfolk           1  136.108258     richmond     richmond
# 446        lewisham           1  136.108258         paul         paul
# 948           lewes           1  136.108258      charles      charles
# 952          exeter           1  136.108258      eustace      eustace
# 738        cotswold           1  136.108258          mrs          mrs
# 328   wolverhampton           1  136.108258        basil        basil
# 577          london           1  136.108258       edward       edward
# 964      sunderland           1  136.108258         john         john
# 584         glasgow           1  136.108258        grace        grace
# 967          dublin           1  136.108258     cuthbert     cuthbert
#
#       gamma_first_name  bf_first_name          surname_l          surname_r  \
# 1006                 4      45.022541             clarke              clark
# 1209                 4      45.022541           vallsnce           vallance
# 393                  4      45.022541  edwards-geathcote  edwards-heathcote
# 37                   4      45.022541             logban             loggan
# 38                   4      45.022541             keppie             kep0ie
# 570                  4      45.022541              abbot             abbott
# 446                  4      45.022541            mathews           matthews
# 948                  4      45.022541               exon               edon
# 952                  4      45.022541            hudgell            budgell
# 738                  4      45.022541       philarmonica       philarmonifa
# 328                  4      45.022541            harwood            harwoof
# 577                  4      45.022541               gray               grey
# 964                  4      45.022541            milburn           millburn
# 584                  4      45.022541           paterson          patterson
# 967                  4      45.022541             butler            buttler
#
#       gamma_surname  bf_surname postcode_l postcode_r
# 1006              3  209.674524   ct15 5lp   ct15 5lp
# 1209              3  209.674524    ub8 3tn    ub8 3tn
# 393               3  209.674524    wa9 2by    wa9 2by
# 37                3  209.674524    s71 2hu    s71 2hu
# 38                3  209.674524    ba4 5jt    ba4 5jt
# 570               3  209.674524   nr14 6jb   nr14 6jb
# 446               3  209.674524   se14 6je   se14 6je
# 948               3  209.674524   bn10 7bd   bn10 7bd
# 952               3  209.674524    ex4 4pw    ex4 4pw
# 738               3  209.674524    gl7 1tt    gl7 1tt
# 328               3  209.674524   wv10 9nj   wv10 9nj
# 577               3  209.674524   sw1a 2jl   sw1a 2jl
# 964               3  209.674524    sr5 1bt    sr5 1bt
# 584               3  209.674524     g2 8ly     g2 8ly
# 967               3  209.674524   ts18 3bp   ts18 3bp

# %%
person_match.match_weight.value_counts()
# Out:
# match_weight
# 8.933053    1352
# 7.625249      85
# 6.666203      60
# 8.312912      60
# 6.699013      28
# Name: count, dtype: int64

# %%
person_match.match_probability.value_counts()
# Out:
# match_probability
# 0.997958    1352
# 0.994961      85
# 0.990250      60
# 0.996865      60
# 0.990467      28
# Name: count, dtype: int64

# %% [markdown]
# Inspect the results
# --

# %%
person_linker.waterfall_chart(person_match_results.as_record_dict(limit=20))
# Out:
# alt.LayerChart(...)

# %%
# Comparison viewer
person_linker.comparison_viewer_dashboard(person_match_results, 
                                          "data/interim/person_match-fuzzy-report-scv.html", 
                                          overwrite=True, num_example_rows=20)
IPython.display.IFrame(src="data/interim/person_match-fuzzy-report-scv.html", width="100%", height=1200)
# Out:
#         <iframe
#             width="100%"
#             height="1200"
#             src="data/interim/person_match-fuzzy-report-scv.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# Export
# --

# %%
person_match.to_csv('data/processed/person_match-fuzzy.csv', index=False)
